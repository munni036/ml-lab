# %% [markdown]
# <a href="https://colab.research.google.com/github/munni036/ml-lab/blob/main/lab1_using_kagglehub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **24bca8159**
#
#
# Datri Saranya Saladi
#
#
# L39+L40
#
# #AIM:  Implementing Linear Regression On Iris Dataset

# %% [markdown]
# #USER INPUT:

# %% [markdown]
# #1.Install Kaggle HUb

# %%
# !pip install kagglehub

# %% [markdown]
# #2.Download Iris dataset using KaggleHub

# %%
import kagglehub
path = kagglehub.dataset_download("uciml/iris")
print(path)
# Out:
# Using Colab cache for faster access to the 'iris' dataset.
# /kaggle/input/iris

# %% [markdown]
# #CODE:

# %% [markdown]
# #3.load iris dataset:

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt




iris = pd.read_csv('/kaggle/input/iris/Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #4.Drop unwanted column

# %%
iris=iris.drop('Id',axis=1)
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #5.Correlation of features:

# %%
iris.drop('Species', axis=1).corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# #6.Scatterplot:

# %%
a=sns.lmplot(x="SepalWidthCm",y="SepalLengthCm",data=iris,aspect=1.5,scatter_kws={'alpha':0.2})
b=sns.lmplot(x="PetalWidthCm",y="SepalLengthCm",data=iris,aspect=1.5,scatter_kws={'alpha':0.2})
c=sns.lmplot(x="PetalLengthCm",y="SepalLengthCm",data=iris,aspect=1.5,scatter_kws={'alpha':0.2})
